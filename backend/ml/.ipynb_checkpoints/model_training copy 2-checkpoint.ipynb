# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from matplotlib import pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, Sequential, Input
from tensorflow.keras.metrics import AUC, BinaryAccuracy
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger

import pandas as pd

from sklearn.metrics import accuracy_score, f1_score, roc_curve, confusion_matrix, roc_auc_score
from sklearn.utils import compute_class_weight

import scipy.stats

import seaborn as sns

print(tf.test.is_built_with_cuda())
gpu_available = tf.config.list_physical_devices('GPU')
print(gpu_available)

from config import img_size, batch_size, model_path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load the data

# %%
def load_data():
    df = pd.read_csv("data/HAM10000_metadata.csv")
    df["label"] = df["dx"].apply(lambda dx: "malignant" if dx in ["akiec", "bcc", "mel"] else "benign") 
    #https://arxiv.org/ftp/arxiv/papers/1803/1803.10417.pdf
    df["image_id"] = df["image_id"].apply(lambda id: f"{id}.jpg")
    df = df.sample(frac=1, random_state=0)
    training_df = df[:8000]
    validation_df = df[8000:9000]
    testing_df = df[9000:]
    classes=["benign", "malignant"]
    
    training_data_generator = ImageDataGenerator(
        rescale=1.0/255,
        rotation_range=360,
        horizontal_flip=True,
        vertical_flip=True,
        brightness_range=[0.95, 1.05],
        zoom_range=[0.85, 1.15]
    )

    validation_data_generator = ImageDataGenerator(
        rescale=1.0/255
    )
    
    testing_data_generator = ImageDataGenerator(
        rescale=1.0/255
    )
    
    training_data = training_data_generator.flow_from_dataframe(
        dataframe= training_df,
        directory="data/images_cropped",
        x_col="image_id",
        y_col="label",
        target_size=(img_size, img_size),
        batch_size=batch_size,
        class_mode="binary",
        classes=classes,
        shuffle=True,
        
    )

    validation_data = validation_data_generator.flow_from_dataframe(
        dataframe=validation_df,
        directory="data/images_cropped",
        x_col="image_id",
        y_col="label",
        target_size=(img_size, img_size),
        batch_size=batch_size,
        class_mode="binary",
        classes=classes,
        shuffle=True
    )

    test_data = testing_data_generator.flow_from_dataframe(
        dataframe=testing_df,
        directory="data/images_cropped",
        x_col="image_id",
        y_col="label",
        target_size=(img_size, img_size),
        class_mode="binary",
        classes=classes,
        batch_size=1015,
        shuffle=False
    )

    return training_data, validation_data, test_data

# %% [markdown]
# ### Creating the model
# Explanation of why the model looks like it does

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras import Model



def create_model():
    #model = Sequential()
    #model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)))
    #model.add(layers.MaxPooling2D((2, 2)))
    #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    #model.add(layers.Flatten())
    #model.add(layers.Dense(64, activation='relu'))
    #model.add(layers.Dense(7, activation='softmax'))

    #model =  Sequential()
    #model.add(layers.Conv2D(filters=96, kernel_size=(11, 11), strides=(4, 4), activation='relu', padding='valid', input_shape=(img_size, img_size, 3)))
    #model.add(layers.MaxPool2D((3, 3), strides=(2, 2), padding='valid'))
    #model.add(layers.Conv2D(filters=256, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu'))
    #model.add(layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='valid'))
    #model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    #model.add(layers.Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    #model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
    #model.add(layers.Flatten())
    #model.add(layers.Dense(4096, activation='relu'))
    #model.add(layers.Dense(4096, activation='relu'))
    #model.add(layers.Dense(1, activation='sigmoid'))
    
    
    
    model = InceptionV3(
        input_shape=(img_size, img_size, 3), pooling="max", include_top=True, classes=1, classifier_activation="sigmoid", weights=None
    )
    
    
    model.compile(optimizer='adam', loss=[BinaryCrossentropy(from_logits=False)], weighted_metrics=[AUC(name="auc",  curve='ROC'), BinaryAccuracy(name="accuracy")])

    return model

# %% [markdown]
# ### Training the model

# %%
def train_model(model, training_data, validation_data, epochs=2):
    
    model_checkpoint_callback = ModelCheckpoint(
        filepath=model_path,
        save_weights_only=False,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True
    )
    
    csv_logger = CSVLogger(f'{model_path}/history.csv', append=False)
    
    # Automatically compute class weights based on label percentage
    y_train = training_data.labels
    class_weight = dict(enumerate(compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)))
    print(f'Class weights: {class_weight}')
    
    history = model.fit(training_data, epochs=epochs, validation_data=validation_data, verbose=1, class_weight=class_weight, callbacks=[model_checkpoint_callback, csv_logger])
    return history

# %% [markdown]
# ### Evaluate the model

# %%
def evaluate_model(model, test_data):
    y_true = test_data[0][1]
    x = test_data[0][0]
    y_score = model.predict(x)
    y_pred = [round(y[0]) for y in y_score]
    
    data_tuple = test_data[0]
    inputs = data_tuple[0]
    predicted = model.predict(inputs)
    ground_truth = [x[1] for x in data_tuple[1]]
    predictions = [x[1] for x in predicted]
    rounded_ground_truth = [round(x) for x in ground_truth]
    rounded_predictions = [round(x) for x in predictions]
    print("---- Ground truth ----")
    print(f"Min: {np.min(y_true)}")
    print(f"Max: {np.max(y_true)}")
    print(f"Mean: {np.mean(y_true)}")
    print("---- Predictions ----")
    print(f"Min: {np.min(y_score)}")
    print(f"Max: {np.max(y_score)}")
    print(f"Mean: {np.mean(y_score)}")
    print(f"Mean rounded: {np.mean(rounded_predictions)}")
    return accuracy_score(rounded_ground_truth, rounded_predictions), f1_score(rounded_ground_truth, rounded_predictions)

# %% [markdown]
# Comments on the results

# %%
def save_model(model, path):
    model.save(path)

# %% [markdown]
# ### Putting it all together

# %%
model = create_model()
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_282 (Conv2D)            (None, 149, 149, 32  864         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_282 (Batch  (None, 149, 149, 32  96         ['conv2d_282[0][0]']
#  Normalization)                 )
#
#  activation_282 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_282[0][0]']
#                                 )
#
#  conv2d_283 (Conv2D)            (None, 147, 147, 32  9216        ['activation_282[0][0]']
#                                 )
#
#  batch_normalization_283 (Batch  (None, 147, 147, 32  96         ['conv2d_283[0][0]']
#  Normalization)                 )
#
#  activation_283 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_283[0][0]']
#                                 )
#
#  conv2d_284 (Conv2D)            (None, 147, 147, 64  18432       ['activation_283[0][0]']
#                                 )
#
#  batch_normalization_284 (Batch  (None, 147, 147, 64  192        ['conv2d_284[0][0]']
#  Normalization)                 )
#
#  activation_284 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_284[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_285 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_285 (Batch  (None, 73, 73, 80)  240         ['conv2d_285[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_285[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 71, 71, 192)  576        ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_286[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_286[0][0]']
#  )
#
#  conv2d_290 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_290 (Batch  (None, 35, 35, 64)  192         ['conv2d_290[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_290[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_290[0][0]']
#
#  batch_normalization_288 (Batch  (None, 35, 35, 48)  144         ['conv2d_288[0][0]']
#  Normalization)
#
#  batch_normalization_291 (Batch  (None, 35, 35, 96)  288         ['conv2d_291[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_288[0][0]']
#
#  activation_291 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_291[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 35, 35, 192)  0          ['max_pooling2d_13[0][0]']
#  ooling2D)
#
#  conv2d_287 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_13[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_288[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_291[0][0]']
#  conv2d_293 (Conv2D)            (None, 35, 35, 32)   6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (Batch  (None, 35, 35, 64)  192         ['conv2d_287[0][0]']
#  Normalization)
#
#  batch_normalization_289 (Batch  (None, 35, 35, 64)  192         ['conv2d_289[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 35, 35, 96)  288         ['conv2d_292[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 35, 35, 32)  96          ['conv2d_293[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_287[0][0]']
#
#  activation_289 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_289[0][0]']
#
#  activation_292 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_292[0][0]']
#
#  activation_293 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_293[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_297 (Batch  (None, 35, 35, 64)  192         ['conv2d_297[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_297[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_297[0][0]']
#
#  batch_normalization_295 (Batch  (None, 35, 35, 48)  144         ['conv2d_295[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 35, 35, 96)  288         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_295[0][0]']
#
#  activation_298 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_298[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_294 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_295[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_298[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 35, 35, 64)   16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_294 (Batch  (None, 35, 35, 64)  192         ['conv2d_294[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 35, 35, 64)  192         ['conv2d_296[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 35, 35, 96)  288         ['conv2d_299[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 35, 35, 64)  192         ['conv2d_300[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_294[0][0]']
#
#  activation_296 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_296[0][0]']
#
#  activation_299 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_299[0][0]']
#
#  activation_300 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_300[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_304 (Batch  (None, 35, 35, 64)  192         ['conv2d_304[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_304[0][0]']
#
#  conv2d_302 (Conv2D)            (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_304[0][0]']
#
#  batch_normalization_302 (Batch  (None, 35, 35, 48)  144         ['conv2d_302[0][0]']
#  Normalization)
#
#  batch_normalization_305 (Batch  (None, 35, 35, 96)  288         ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_302[0][0]']
#
#  activation_305 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_305[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_301 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_302[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_305[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 35, 35, 64)   18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_301 (Batch  (None, 35, 35, 64)  192         ['conv2d_301[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 35, 35, 64)  192         ['conv2d_303[0][0]']
#  Normalization)
#
#  batch_normalization_306 (Batch  (None, 35, 35, 96)  288         ['conv2d_306[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 35, 35, 64)  192         ['conv2d_307[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_301[0][0]']
#
#  activation_303 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_303[0][0]']
#
#  activation_306 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_306[0][0]']
#
#  activation_307 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_307[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_309 (Batch  (None, 35, 35, 64)  192         ['conv2d_309[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_309[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_309[0][0]']
#
#  batch_normalization_310 (Batch  (None, 35, 35, 96)  288         ['conv2d_310[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_310[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 17, 17, 96)   82944       ['activation_310[0][0]']
#
#  batch_normalization_308 (Batch  (None, 17, 17, 384)  1152       ['conv2d_308[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 17, 17, 96)  288         ['conv2d_311[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_308[0][0]']
#
#  activation_311 (Activation)    (None, 17, 17, 96)   0           ['batch_normalization_311[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_14[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_316 (Batch  (None, 17, 17, 128)  384        ['conv2d_316[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_316[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_316[0][0]']
#
#  batch_normalization_317 (Batch  (None, 17, 17, 128)  384        ['conv2d_317[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_317[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_317[0][0]']
#
#  batch_normalization_313 (Batch  (None, 17, 17, 128)  384        ['conv2d_313[0][0]']
#  Normalization)
#
#  batch_normalization_318 (Batch  (None, 17, 17, 128)  384        ['conv2d_318[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_313[0][0]']
#
#  activation_318 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_318[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_313[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_318[0][0]']
#
#  batch_normalization_314 (Batch  (None, 17, 17, 128)  384        ['conv2d_314[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 17, 17, 128)  384        ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_314[0][0]']
#
#  activation_319 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_319[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_312 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_314[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_319[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_312 (Batch  (None, 17, 17, 192)  576        ['conv2d_312[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 17, 17, 192)  576        ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 17, 17, 192)  576        ['conv2d_320[0][0]']
#  Normalization)
#
#  batch_normalization_321 (Batch  (None, 17, 17, 192)  576        ['conv2d_321[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_312[0][0]']
#
#  activation_315 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_315[0][0]']
#
#  activation_320 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_320[0][0]']
#
#  activation_321 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_321[0][0]']
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_326 (Batch  (None, 17, 17, 160)  480        ['conv2d_326[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_326[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_326[0][0]']
#
#  batch_normalization_327 (Batch  (None, 17, 17, 160)  480        ['conv2d_327[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_327[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_327[0][0]']
#
#  batch_normalization_323 (Batch  (None, 17, 17, 160)  480        ['conv2d_323[0][0]']
#  Normalization)
#
#  batch_normalization_328 (Batch  (None, 17, 17, 160)  480        ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_323[0][0]']
#
#  activation_328 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_328[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_323[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_328[0][0]']
#
#  batch_normalization_324 (Batch  (None, 17, 17, 160)  480        ['conv2d_324[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 17, 17, 160)  480        ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_324[0][0]']
#
#  activation_329 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_329[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_322 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_324[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_329[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_322 (Batch  (None, 17, 17, 192)  576        ['conv2d_322[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 17, 17, 192)  576        ['conv2d_325[0][0]']
#  Normalization)
#
#  batch_normalization_330 (Batch  (None, 17, 17, 192)  576        ['conv2d_330[0][0]']
#  Normalization)
#
#  batch_normalization_331 (Batch  (None, 17, 17, 192)  576        ['conv2d_331[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_322[0][0]']
#
#  activation_325 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_325[0][0]']
#
#  activation_330 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_330[0][0]']
#
#  activation_331 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_331[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#  conv2d_336 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_336 (Batch  (None, 17, 17, 160)  480        ['conv2d_336[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_336[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_336[0][0]']
#
#  batch_normalization_337 (Batch  (None, 17, 17, 160)  480        ['conv2d_337[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_337[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_337[0][0]']
#
#  batch_normalization_333 (Batch  (None, 17, 17, 160)  480        ['conv2d_333[0][0]']
#  Normalization)
#
#  batch_normalization_338 (Batch  (None, 17, 17, 160)  480        ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_333[0][0]']
#
#  activation_338 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_338[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_333[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_338[0][0]']
#
#  batch_normalization_334 (Batch  (None, 17, 17, 160)  480        ['conv2d_334[0][0]']
#  Normalization)
#
#  batch_normalization_339 (Batch  (None, 17, 17, 160)  480        ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_334 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_334[0][0]']
#
#  activation_339 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_339[0][0]']
#
#  average_pooling2d_32 (AverageP  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_332 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_334[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_339[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_32[0][0]']
#
#  batch_normalization_332 (Batch  (None, 17, 17, 192)  576        ['conv2d_332[0][0]']
#  Normalization)
#
#  batch_normalization_335 (Batch  (None, 17, 17, 192)  576        ['conv2d_335[0][0]']
#  Normalization)
#
#  batch_normalization_340 (Batch  (None, 17, 17, 192)  576        ['conv2d_340[0][0]']
#  Normalization)
#
#  batch_normalization_341 (Batch  (None, 17, 17, 192)  576        ['conv2d_341[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_332[0][0]']
#
#  activation_335 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_335[0][0]']
#
#  activation_340 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_340[0][0]']
#
#  activation_341 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_341[0][0]']
# ...
#  conv2d_362 (Conv2D)            (None, 8, 8, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_362 (Batch  (None, 8, 8, 448)   1344        ['conv2d_362[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_362[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_362[0][0]']
#
#  batch_normalization_359 (Batch  (None, 8, 8, 384)   1152        ['conv2d_359[0][0]']
#  Normalization)
#
#  batch_normalization_363 (Batch  (None, 8, 8, 384)   1152        ['conv2d_363[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_359[0][0]']
#
#  activation_363 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_363[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_359[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_363[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_363[0][0]']
#
#  average_pooling2d_34 (AverageP  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_358 (Conv2D)            (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_360 (Batch  (None, 8, 8, 384)   1152        ['conv2d_360[0][0]']
#  Normalization)
#
#  batch_normalization_361 (Batch  (None, 8, 8, 384)   1152        ['conv2d_361[0][0]']
#  Normalization)
#
#  batch_normalization_364 (Batch  (None, 8, 8, 384)   1152        ['conv2d_364[0][0]']
#  Normalization)
#
#  batch_normalization_365 (Batch  (None, 8, 8, 384)   1152        ['conv2d_365[0][0]']
#  Normalization)
#
#  conv2d_366 (Conv2D)            (None, 8, 8, 192)    245760      ['average_pooling2d_34[0][0]']
#
#  batch_normalization_358 (Batch  (None, 8, 8, 320)   960         ['conv2d_358[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_360[0][0]']
#
#  activation_361 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_361[0][0]']
#
#  activation_364 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_364[0][0]']
#
#  activation_365 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_365[0][0]']
#
#  batch_normalization_366 (Batch  (None, 8, 8, 192)   576         ['conv2d_366[0][0]']
#  Normalization)
#
#  activation_358 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_358[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_360[0][0]',
#                                                                   'activation_361[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 8, 8, 768)    0           ['activation_364[0][0]',
#                                                                   'activation_365[0][0]']
#
#  activation_366 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_366[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_358[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_6[0][0]',
#                                                                   'activation_366[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_371 (Batch  (None, 8, 8, 448)   1344        ['conv2d_371[0][0]']
#  Normalization)
#
#  activation_371 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_371[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_371[0][0]']
#
#  batch_normalization_368 (Batch  (None, 8, 8, 384)   1152        ['conv2d_368[0][0]']
#  Normalization)
#
#  batch_normalization_372 (Batch  (None, 8, 8, 384)   1152        ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_368[0][0]']
#
#  activation_372 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_372[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_370 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_368[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_372[0][0]']
#
#  conv2d_374 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_372[0][0]']
#
#  average_pooling2d_35 (AverageP  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_367 (Conv2D)            (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_369 (Batch  (None, 8, 8, 384)   1152        ['conv2d_369[0][0]']
#  Normalization)
#
#  batch_normalization_370 (Batch  (None, 8, 8, 384)   1152        ['conv2d_370[0][0]']
#  Normalization)
#
#  batch_normalization_373 (Batch  (None, 8, 8, 384)   1152        ['conv2d_373[0][0]']
#  Normalization)
#
#  batch_normalization_374 (Batch  (None, 8, 8, 384)   1152        ['conv2d_374[0][0]']
#  Normalization)
#
#  conv2d_375 (Conv2D)            (None, 8, 8, 192)    393216      ['average_pooling2d_35[0][0]']
#
#  batch_normalization_367 (Batch  (None, 8, 8, 320)   960         ['conv2d_367[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_369[0][0]']
#
#  activation_370 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_370[0][0]']
#
#  activation_373 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_373[0][0]']
#
#  activation_374 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_374[0][0]']
#
#  batch_normalization_375 (Batch  (None, 8, 8, 192)   576         ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_367 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_367[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_369[0][0]',
#                                                                   'activation_370[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 8, 768)    0           ['activation_373[0][0]',
#                                                                   'activation_374[0][0]']
#
#  activation_375 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_375[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_367[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_7[0][0]',
#                                                                   'activation_375[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['mixed10[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1)            2049        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
training_data, validation_data, test_data = load_data()
training_result = train_model(model, training_data, validation_data, epochs=240)
# Out:
# Found 8000 validated image filenames belonging to 2 classes.
# Found 1000 validated image filenames belonging to 2 classes.
# Found 1015 validated image filenames belonging to 2 classes.
# Class weights: {0: 0.6208288064566196, 1: 2.5690430314707773}
# Epoch 1/240
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002083AD60798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002083AD60798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 500/500 [==============================] - ETA: 0s - loss: 0.6299 - auc: 0.7129 - accuracy: 0.6669WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002083986C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000002083986C5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x00000208398360D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x00000208398360D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000208390010D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000208390010D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 164s 317ms/step - loss: 0.6299 - auc: 0.7129 - accuracy: 0.6669 - val_loss: 0.7783 - val_auc: 0.7500 - val_accuracy: 0.5130
# Epoch 2/240
# 500/500 [==============================] - ETA: 0s - loss: 0.5603 - auc: 0.7604 - accuracy: 0.6973WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020876A58F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020876A58F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000207C6977438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000207C6977438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 159s 318ms/step - loss: 0.5603 - auc: 0.7604 - accuracy: 0.6973 - val_loss: 0.5604 - val_auc: 0.7332 - val_accuracy: 0.5760
# Epoch 3/240
# 500/500 [==============================] - ETA: 0s - loss: 0.5523 - auc: 0.7800 - accuracy: 0.7122WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x000002087C276AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x000002087C276AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x0000020866EF1168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x0000020866EF1168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 159s 318ms/step - loss: 0.5523 - auc: 0.7800 - accuracy: 0.7122 - val_loss: 1.1011 - val_auc: 0.5770 - val_accuracy: 0.7880
# Epoch 4/240
# 500/500 [==============================] - ETA: 0s - loss: 0.5220 - auc: 0.7962 - accuracy: 0.7272WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x00000208624924C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x00000208624924C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000208624684C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000208624684C8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 158s 317ms/step - loss: 0.5220 - auc: 0.7962 - accuracy: 0.7272 - val_loss: 0.4408 - val_auc: 0.7684 - val_accuracy: 0.7990
# Epoch 5/240
# 500/500 [==============================] - 126s 251ms/step - loss: 0.5192 - auc: 0.8064 - accuracy: 0.7354 - val_loss: 0.4607 - val_auc: 0.8000 - val_accuracy: 0.7650
# Epoch 6/240
# 500/500 [==============================] - ETA: 0s - loss: 0.5074 - auc: 0.8081 - accuracy: 0.7348WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x00
240
# 500/500 [==============================] - 127s 253ms/step - loss: 0.4787 - auc: 0.8320 - accuracy: 0.7680 - val_loss: 0.3904 - val_auc: 0.8631 - val_accuracy: 0.7690
# Epoch 22/240
# 500/500 [==============================] - 126s 251ms/step - loss: 0.4808 - auc: 0.8347 - accuracy: 0.7612 - val_loss: 0.4208 - val_auc: 0.8504 - val_accuracy: 0.7940
# Epoch 23/240
# 500/500 [==============================] - 127s 255ms/step - loss: 0.4785 - auc: 0.8342 - accuracy: 0.7651 - val_loss: 0.4467 - val_auc: 0.8565 - val_accuracy: 0.7540
# Epoch 24/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4804 - auc: 0.8349 - accuracy: 0.7628 - val_loss: 0.5742 - val_auc: 0.8199 - val_accuracy: 0.7080
# Epoch 25/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.4722 - auc: 0.8396 - accuracy: 0.7655 - val_loss: 0.3868 - val_auc: 0.8504 - val_accuracy: 0.8080
# Epoch 26/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.4734 - auc: 0.8396 - accuracy: 0.7651 - val_loss: 0.4186 - val_auc: 0.8447 - val_accuracy: 0.7800
# Epoch 27/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4672 - auc: 0.8453 - accuracy: 0.7751 - val_loss: 0.4074 - val_auc: 0.8768 - val_accuracy: 0.7600
# Epoch 28/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4716 - auc: 0.8394 - accuracy: 0.7675 - val_loss: 0.4608 - val_auc: 0.8538 - val_accuracy: 0.7230
# Epoch 29/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4645 - auc: 0.8438 - accuracy: 0.7719 - val_loss: 0.3734 - val_auc: 0.8784 - val_accuracy: 0.7980
# Epoch 30/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.4579 - auc: 0.8496 - accuracy: 0.7777 - val_loss: 0.4376 - val_auc: 0.8777 - val_accuracy: 0.7450
# Epoch 31/240
# 500/500 [==============================] - 127s 253ms/step - loss: 0.4627 - auc: 0.8482 - accuracy: 0.7754 - val_loss: 0.4969 - val_auc: 0.7618 - val_accuracy: 0.7320
# Epoch 32/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4637 - auc: 0.8460 - accuracy: 0.7718 - val_loss: 0.4057 - val_auc: 0.8374 - val_accuracy: 0.7820
# Epoch 33/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4605 - auc: 0.8467 - accuracy: 0.7687 - val_loss: 0.4615 - val_auc: 0.8484 - val_accuracy: 0.7140
# Epoch 34/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4607 - auc: 0.8497 - accuracy: 0.7712 - val_loss: 0.4588 - val_auc: 0.8600 - val_accuracy: 0.7240
# Epoch 35/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.4568 - auc: 0.8513 - accuracy: 0.7748 - val_loss: 0.4919 - val_auc: 0.8260 - val_accuracy: 0.7060
# Epoch 36/240
# 500/500 [==============================] - 126s 252ms/step - loss: 0.4656 - auc: 0.8485 - accuracy: 0.7703 - val_loss: 0.4461 - val_auc: 0.8821 - val_accuracy: 0.7480
# Epoch 37/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.4556 - auc: 0.8542 - accuracy: 0.7747 - val_loss: 0.3700 - val_auc: 0.8740 - val_accuracy: 0.8090
# Epoch 38/240
# 500/500 [==============================] - ETA: 0s - loss: 0.4530 - auc: 0.8521 - accuracy: 0.7814WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020848786F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020848786F78> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x000002085E75F3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x000002085E75F3A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 162s 323ms/step - loss: 0.4530 - auc: 0.8521 - accuracy: 0.7814 - val_loss: 0.3810 - val_auc: 0.8767 - val_accuracy: 0.8260
# Epoch 39/240
# 500/500 [==============================] - 127s 253ms/step - loss: 0.
240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.4145 - auc: 0.8817 - accuracy: 0.7981 - val_loss: 0.3144 - val_auc: 0.9085 - val_accuracy: 0.8480
# Epoch 93/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.4128 - auc: 0.8821 - accuracy: 0.7983 - val_loss: 0.3482 - val_auc: 0.9150 - val_accuracy: 0.8230
# Epoch 94/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.4142 - auc: 0.8798 - accuracy: 0.8006 - val_loss: 0.3628 - val_auc: 0.8512 - val_accuracy: 0.8370
# Epoch 95/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.4076 - auc: 0.8851 - accuracy: 0.8056 - val_loss: 0.3280 - val_auc: 0.9039 - val_accuracy: 0.8250
# Epoch 96/240
# 500/500 [==============================] - 128s 257ms/step - loss: 0.4122 - auc: 0.8815 - accuracy: 0.8042 - val_loss: 0.3537 - val_auc: 0.8768 - val_accuracy: 0.8040
# Epoch 97/240
# 500/500 [==============================] - 130s 260ms/step - loss: 0.4079 - auc: 0.8847 - accuracy: 0.8029 - val_loss: 0.3186 - val_auc: 0.8965 - val_accuracy: 0.8270
# Epoch 98/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.4072 - auc: 0.8856 - accuracy: 0.8088 - val_loss: 0.3243 - val_auc: 0.8908 - val_accuracy: 0.8370
# Epoch 99/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.4171 - auc: 0.8823 - accuracy: 0.8040 - val_loss: 0.3387 - val_auc: 0.8885 - val_accuracy: 0.8350
# Epoch 100/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.4018 - auc: 0.8899 - accuracy: 0.8130 - val_loss: 0.3247 - val_auc: 0.8888 - val_accuracy: 0.8480
# Epoch 101/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.4047 - auc: 0.8886 - accuracy: 0.8076 - val_loss: 0.3130 - val_auc: 0.9086 - val_accuracy: 0.8350
# Epoch 102/240
# 500/500 [==============================] - 131s 261ms/step - loss: 0.3995 - auc: 0.8881 - accuracy: 0.8071 - val_loss: 0.3337 - val_auc: 0.8987 - val_accuracy: 0.8300
# Epoch 103/240
# 500/500 [==============================] - 131s 261ms/step - loss: 0.4121 - auc: 0.8832 - accuracy: 0.8033 - val_loss: 0.3275 - val_auc: 0.9038 - val_accuracy: 0.8380
# Epoch 104/240
# 500/500 [==============================] - 130s 260ms/step - loss: 0.3994 - auc: 0.8902 - accuracy: 0.8127 - val_loss: 0.3236 - val_auc: 0.9120 - val_accuracy: 0.8330
# Epoch 105/240
# 500/500 [==============================] - ETA: 0s - loss: 0.4021 - auc: 0.8879 - accuracy: 0.8107WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020877D5CEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x0000020877D5CEE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x0000020877D5CD38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
# Epoch 164/240
# 500/500 [==============================] - 131s 262ms/step - loss: 0.3667 - auc: 0.9090 - accuracy: 0.8259 - val_loss: 0.3263 - val_auc: 0.8866 - val_accuracy: 0.8320
# Epoch 165/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3667 - auc: 0.9093 - accuracy: 0.8280 - val_loss: 0.3156 - val_auc: 0.9096 - val_accuracy: 0.8380
# Epoch 166/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3660 - auc: 0.9091 - accuracy: 0.8314 - val_loss: 0.3130 - val_auc: 0.9000 - val_accuracy: 0.8500
# Epoch 167/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3548 - auc: 0.9142 - accuracy: 0.8358 - val_loss: 0.3098 - val_auc: 0.9007 - val_accuracy: 0.8470
# Epoch 168/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3641 - auc: 0.9100 - accuracy: 0.8266 - val_loss: 0.3461 - val_auc: 0.8962 - val_accuracy: 0.8270
# Epoch 169/240
# 500/500 [==============================] - 135s 269ms/step - loss: 0.3677 - auc: 0.9089 - accuracy: 0.8315 - val_loss: 0.3487 - val_auc: 0.9095 - val_accuracy: 0.8360
# Epoch 170/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3639 - auc: 0.9106 - accuracy: 0.8326 - val_loss: 0.3588 - val_auc: 0.9014 - val_accuracy: 0.8140
# Epoch 171/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3595 - auc: 0.9137 - accuracy: 0.8314 - val_loss: 0.3190 - val_auc: 0.9111 - val_accuracy: 0.8440
# Epoch 172/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3622 - auc: 0.9115 - accuracy: 0.8306 - val_loss: 0.3381 - val_auc: 0.9121 - val_accuracy: 0.8310
# Epoch 173/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3626 - auc: 0.9119 - accuracy: 0.8277 - val_loss: 0.3173 - val_auc: 0.8979 - val_accuracy: 0.8450
# Epoch 174/240
# 500/500 [==============================] - 131s 261ms/step - loss: 0.3575 - auc: 0.9148 - accuracy: 0.8347 - val_loss: 0.3033 - val_auc: 0.9080 - val_accuracy: 0.8500
# Epoch 175/240
# 500/500 [==============================] - 129s 259ms/step - loss: 0.3579 - auc: 0.9150 - accuracy: 0.8389 - val_loss: 0.3257 - val_auc: 0.8909 - val_accuracy: 0.8390
# Epoch 176/240
# 500/500 [==============================] - 131s 261ms/step - loss: 0.3515 - auc: 0.9176 - accuracy: 0.8381 - val_loss: 0.3205 - val_auc: 0.9001 - val_accuracy: 0.8450
# Epoch 177/240
# 500/500 [==============================] - 130s 259ms/step - loss: 0.3687 - auc: 0.9083 - accuracy: 0.8257 - val_loss: 0.3297 - val_auc: 0.8860 - val_accuracy: 0.8380
# Epoch 178/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3468 - auc: 0.9196 - accuracy: 0.8352 - val_loss: 0.3285 - val_auc: 0.8952 - val_accuracy: 0.8380
# Epoch 179/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3575 - auc: 0.9145 - accuracy: 0.8320 - val_loss: 0.3314 - val_auc: 0.9027 - val_accuracy: 0.8370
# Epoch 180/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3567 - auc: 0.9152 - accuracy: 0.8351 - val_loss: 0.3173 - val_auc: 0.8939 - val_accuracy: 0.8500
# Epoch 181/240
# 500/500 [==============================] - 131s 262ms/step - loss: 0.3545 - auc: 0.9164 - accuracy: 0.8360 - val_loss: 0.3582 - val_auc: 0.8923 - val_accuracy: 0.8210
# Epoch 182/240
# 500/500 [==============================] - 130s 260ms/step - loss: 0.3638 - auc: 0.9122 - accuracy: 0.8289 - val_loss: 0.3037 - val_auc: 0.9028 - val_accuracy: 0.8580
# Epoch 183/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3495 - auc: 0.9180 - accuracy: 0.8333 - val_loss: 0.3148 - val_auc: 0.9079 - val_accuracy: 0.8390
# Epoch 184/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3516 - auc: 0.9175 - accuracy: 0.8373 - val_loss: 0.3225 - val_auc: 0.8986 - val_accuracy: 0.8370
# Epoch 185/240
# 500/500 [==============================] - ETA: 0s - loss: 0.3545 - auc: 0.9162 - accuracy: 0.8350WARNING:tensorflow:AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x000002087B4BE678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x000002087B4BE678> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000207CE0CB048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x00000207CE0CB048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: models/test\checkpoint\assets
# 500/500 [==============================] - 164s 328ms/step - loss: 0.3545 - auc: 0.9162 - accuracy: 0.8350 - val_loss: 0.2845 - val_auc: 0.9169 - val_accuracy: 0.8690
# Epoch 186/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3524 - auc: 0.9175 - accuracy: 0.8347 - val_loss: 0.3203 - val_auc: 0.9123 - val_accuracy: 0.8520
# Epoch 187/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3489 - auc: 0.9175 - accuracy: 0.8358 - val_loss: 0.3690 - val_auc: 0.8931 - val_accuracy: 0.8180
# Epoch 188/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3492 - auc: 0.9195 - accuracy: 0.8402 - val_loss: 0.3548 - val_auc: 0.8918 - val_accuracy: 0.8280
# Epoch 189/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3514 - auc: 0.9180 - accuracy: 0.8342 - val_loss: 0.3053 - val_auc: 0.9031 - val_accuracy: 0.8410
# Epoch 190/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3443 - auc: 0.9204 - accuracy: 0.8421 - val_loss: 0.3763 - val_auc: 0.8925 - val_accuracy: 0.8110
# Epoch 191/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3564 - auc: 0.9160 - accuracy: 0.8350 - val_loss: 0.3314 - val_auc: 0.8854 - val_accuracy: 0.8300
# Epoch 192/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3465 - auc: 0.9201 - accuracy: 0.8447 - val_loss: 0.3207 - val_auc: 0.8994 - val_accuracy: 0.8510
# Epoch 193/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3453 - auc: 0.9203 - accuracy: 0.8434 - val_loss: 0.2920 - val_auc: 0.9130 - val_accuracy: 0.8570
# Epoch 194/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3422 - auc: 0.9217 - accuracy: 0.8483 - val_loss: 0.3079 - val_auc: 0.9095 - val_accuracy: 0.8520
# Epoch 195/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3480 - auc: 0.9194 - accuracy: 0.8436 - val_loss: 0.3109 - val_auc: 0.9037 - val_accuracy: 0.8560
# Epoch 196/240
# 500/500 [==============================] - 127s 253ms/step - loss: 0.3403 - auc: 0.9225 - accuracy: 0.8448 - val_loss: 0.2863 - val_auc: 0.9146 - val_accuracy: 0.8520
# Epoch 197/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3640 - auc: 0.9134 - accuracy: 0.8307 - val_loss: 0.2907 - val_auc: 0.9165 - val_accuracy: 0.8600
# Epoch 198/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3430 - auc: 0.9215 - accuracy: 0.8422 - val_loss: 0.3196 - val_auc: 0.8995 - val_accuracy: 0.8500
# Epoch 199/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3435 - auc: 0.9210 - accuracy: 0.8414 - val_loss: 0.3210 - val_auc: 0.9022 - val_accuracy: 0.8380
# Epoch 200/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3441 - auc: 0.9212 - accuracy: 0.8377 - val_loss: 0.3772 - val_auc: 0.8997 - val_accuracy: 0.8070
# Epoch 201/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3510 - auc: 0.9184 - accuracy: 0.8394 - val_loss: 0.3023 - val_auc: 0.9212 - val_accuracy: 0.8580
# Epoch 202/240
# 500/500 [==============================] - 127s 253ms/step - loss: 0.3402 - auc: 0.9226 - accuracy: 0.8415 - val_loss: 0.4019 - val_auc: 0.8700 - val_accuracy: 0.8080
# Epoch 203/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3377 - auc: 0.9244 - accuracy: 0.8439 - val_loss: 0.3162 - val_auc: 0.9083 - val_accuracy: 0.8490
# Epoch 204/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3411 - auc: 0.9234 - accuracy: 0.8482 - val_loss: 0.3034 - val_auc: 0.9124 - val_accuracy: 0.8640
# Epoch 205/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3400 - auc: 0.9226 - accuracy: 0.8394 - val_loss: 0.4226 - val_auc: 0.8933 - val_accuracy: 0.8070
# Epoch 206/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3391 - auc: 0.9238 - accuracy: 0.8473 - val_loss: 0.3423 - val_auc: 0.8892 - val_accuracy: 0.8280
# Epoch 207/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3371 - auc: 0.9240 - accuracy: 0.8472 - val_loss: 0.2823 - val_auc: 0.9241 - val_accuracy: 0.8640
# Epoch 208/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3464 - auc: 0.9200 - accuracy: 0.8394 - val_loss: 0.3457 - val_auc: 0.8958 - val_accuracy: 0.8420
# Epoch 209/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3417 - auc: 0.9216 - accuracy: 0.8454 - val_loss: 0.3160 - val_auc: 0.9079 - val_accuracy: 0.8550
# Epoch 210/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3405 - auc: 0.9234 - accuracy: 0.8399 - val_loss: 0.3274 - val_auc: 0.9049 - val_accuracy: 0.8360
# Epoch 211/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3483 - auc: 0.9194 - accuracy: 0.8353 - val_loss: 0.2800 - val_auc: 0.9214 - val_accuracy: 0.8660
# Epoch 212/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3339 - auc: 0.9252 - accuracy: 0.8428 - val_loss: 0.2828 - val_auc: 0.9192 - val_accuracy: 0.8630
# Epoch 213/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3305 - auc: 0.9282 - accuracy: 0.8503 - val_loss: 0.3209 - val_auc: 0.9128 - val_accuracy: 0.8460
# Epoch 214/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3376 - auc: 0.9226 - accuracy: 0.8472 - val_loss: 0.2957 - val_auc: 0.9151 - val_accuracy: 0.8580
# Epoch 215/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3337 - auc: 0.9261 - accuracy: 0.8488 - val_loss: 0.3826 - val_auc: 0.8653 - val_accuracy: 0.8470
# Epoch 216/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3313 - auc: 0.9271 - accuracy: 0.8431 - val_loss: 0.2897 - val_auc: 0.9196 - val_accuracy: 0.8630
# Epoch 217/240
# 500/500 [==============================] - 128s 257ms/step - loss: 0.3327 - auc: 0.9253 - accuracy: 0.8451 - val_loss: 0.3582 - val_auc: 0.9071 - val_accuracy: 0.8260
# Epoch 218/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3315 - auc: 0.9258 - accuracy: 0.8483 - val_loss: 0.3460 - val_auc: 0.8963 - val_accuracy: 0.8340
# Epoch 219/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3233 - auc: 0.9297 - accuracy: 0.8557 - val_loss: 0.3378 - val_auc: 0.8966 - val_accuracy: 0.8330
# Epoch 220/240
# 500/500 [==============================] - 127s 255ms/step - loss: 0.3341 - auc: 0.9255 - accuracy: 0.8453 - val_loss: 0.3036 - val_auc: 0.9239 - val_accuracy: 0.8640
# Epoch 221/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3300 - auc: 0.9284 - accuracy: 0.8439 - val_loss: 0.3051 - val_auc: 0.9096 - val_accuracy: 0.8580
# Epoch 222/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3328 - auc: 0.9266 - accuracy: 0.8494 - val_loss: 0.3215 - val_auc: 0.9013 - val_accuracy: 0.8550
# Epoch 223/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3251 - auc: 0.9302 - accuracy: 0.8502 - val_loss: 0.3459 - val_auc: 0.8874 - val_accuracy: 0.8210
# Epoch 224/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3277 - auc: 0.9273 - accuracy: 0.8502 - val_loss: 0.3096 - val_auc: 0.9075 - val_accuracy: 0.8590
# Epoch 225/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3369 - auc: 0.9257 - accuracy: 0.8497 - val_loss: 0.3308 - val_auc: 0.9171 - val_accuracy: 0.8550
# Epoch 226/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3247 - auc: 0.9289 - accuracy: 0.8560 - val_loss: 0.2802 - val_auc: 0.9207 - val_accuracy: 0.8630
# Epoch 227/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3286 - auc: 0.9282 - accuracy: 0.8481 - val_loss: 0.2856 - val_auc: 0.9197 - val_accuracy: 0.8670
# Epoch 228/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3296 - auc: 0.9293 - accuracy: 0.8524 - val_loss: 0.3077 - val_auc: 0.9056 - val_accuracy: 0.8420
# Epoch 229/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3245 - auc: 0.9313 - accuracy: 0.8549 - val_loss: 0.2904 - val_auc: 0.9216 - val_accuracy: 0.8580
# Epoch 230/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3231 - auc: 0.9306 - accuracy: 0.8527 - val_loss: 0.3056 - val_auc: 0.9125 - val_accuracy: 0.8490
# Epoch 231/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3274 - auc: 0.9294 - accuracy: 0.8505 - val_loss: 0.3180 - val_auc: 0.9044 - val_accuracy: 0.8520
# Epoch 232/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3248 - auc: 0.9308 - accuracy: 0.8476 - val_loss: 0.3320 - val_auc: 0.9121 - val_accuracy: 0.8420
# Epoch 233/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3280 - auc: 0.9301 - accuracy: 0.8510 - val_loss: 0.2921 - val_auc: 0.9115 - val_accuracy: 0.8510
# Epoch 234/240
# 500/500 [==============================] - 129s 257ms/step - loss: 0.3199 - auc: 0.9324 - accuracy: 0.8510 - val_loss: 0.3034 - val_auc: 0.9100 - val_accuracy: 0.8590
# Epoch 235/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3287 - auc: 0.9294 - accuracy: 0.8529 - val_loss: 0.3312 - val_auc: 0.9052 - val_accuracy: 0.8490
# Epoch 236/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3251 - auc: 0.9291 - accuracy: 0.8562 - val_loss: 0.3096 - val_auc: 0.9026 - val_accuracy: 0.8570
# Epoch 237/240
# 500/500 [==============================] - 128s 255ms/step - loss: 0.3225 - auc: 0.9319 - accuracy: 0.8528 - val_loss: 0.2972 - val_auc: 0.9132 - val_accuracy: 0.8510
# Epoch 238/240
# 500/500 [==============================] - 127s 254ms/step - loss: 0.3218 - auc: 0.9312 - accuracy: 0.8578 - val_loss: 0.3352 - val_auc: 0.9078 - val_accuracy: 0.8530
# Epoch 239/240
# 500/500 [==============================] - 129s 258ms/step - loss: 0.3138 - auc: 0.9337 - accuracy: 0.8576 - val_loss: 0.3409 - val_auc: 0.8912 - val_accuracy: 0.8260
# Epoch 240/240
# 500/500 [==============================] - 128s 256ms/step - loss: 0.3126 - auc: 0.9341 - accuracy: 0.8588 - val_loss: 0.3284 - val_auc: 0.9064 - val_accuracy: 0.8400

# %%
#save_model(model, model_path)

# %%
model = tf.keras.models.load_model(model_path)
training_data, validation_data, test_data = load_data()
# Out:
# Found 8000 validated image filenames belonging to 2 classes.
# Found 1000 validated image filenames belonging to 2 classes.
# Found 1015 validated image filenames belonging to 2 classes.

# %%
# test_result = evaluate_model(model, test_data)
# print(f"Accuracy: {test_result[0]}")
# print(f"F1-score: {test_result[1]}")

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(training_result.history)

hist_csv_file = f'./{model_path}/history.csv'

hist_df.to_csv(hist_csv_file)

# %%
history = pd.read_csv(hist_csv_file)

# %%
labels = ["loss", "val_loss"]
for label in labels:
     plt.plot(history[label])
plt.legend(labels)
plt.show()

# %%
labels = ["accuracy", "val_accuracy"]
for label in labels:
    plt.plot(history[label])
plt.legend(labels)
plt.show()

# %%
labels = ["auc", "val_auc"]
for label in labels:
    plt.plot(history[label])
plt.legend(labels)
plt.show()

# %%
def plot_cm(y_true, y_score, threshold=0.5):
    y_pred = [0 if y[0] < threshold else 1 for y in y_score]
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt="d")
    plt.title(f'Confusion matrix')
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

def plot_roc(y_true, y_score):
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
    
    # plot the roc curve for the model
    plt.figure(figsize=(8,8))
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='model')
    plt.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
    # axis labels
    plt.title(f'Receiver operating characteristic (ROC) with {round(roc_auc_score(y_true, y_score), 3)} AUC')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show()
    
def plot_prediction_distributions(y_true, y_score, threshold):
    test_y = y_true
    predicted_y_probs = y_score

    def estimate_beta(X):
        xbar = np.mean(X)
        vbar = np.var(X,ddof=1)
        alphahat = xbar*(xbar*(1-xbar)/vbar - 1)
        betahat = (1-xbar)*(xbar*(1-xbar)/vbar - 1)
        return alphahat, betahat

    positive_beta_estimates = estimate_beta(predicted_y_probs[test_y == 1])
    negative_beta_estimates = estimate_beta(predicted_y_probs[test_y == 0])

    unit_interval = np.linspace(0,1,100)
    plt.plot(unit_interval, scipy.stats.beta.pdf(unit_interval, *positive_beta_estimates), c='r', label="positive")
    plt.plot(unit_interval, scipy.stats.beta.pdf(unit_interval, *negative_beta_estimates), c='g', label="negative")

    # Show the threshold.
    plt.axvline(threshold, c='black', ls='dashed')
    plt.xlim(0,1)
    plt.yticks([], [])

    # Add labels
    plt.legend()

# %%
y_true = test_data[0][1]
x = test_data[0][0]
y_score = model.predict(x)

# %%
plot_roc(y_true, y_score)
# Out:
# Best Threshold=0.197710, G-Mean=0.828

# %%
plot_prediction_distributions(y_true, y_score, 0.197710)

# %%
plot_prediction_distributions(y_true, y_score, 0.5)

# %%
# Confusion matrix when using the best threshold
plot_cm(y_true, y_score, 0.197710)

# %%
# Confusion matrix when using default 0.5 as threshold
plot_cm(y_true, y_score, 0.5)

# %%
print(training_data[0][0][0].shape)
img = training_data[0][0][0]


images = tf.Variable(np.expand_dims(img, axis=0), dtype=float)

with tf.GradientTape() as tape:
    pred = model(images, training=False)
    class_idxs_sorted = np.argsort(pred.numpy().flatten())[::-1]
    loss = pred[0][class_idxs_sorted[0]]
    
grads = tape.gradient(loss, images)

dgrad_abs = tf.math.abs(grads)

dgrad_max_ = np.max(dgrad_abs, axis=3)[0]

arr_min, arr_max  = np.min(dgrad_max_), np.max(dgrad_max_)
grad_eval = (dgrad_max_ - arr_min) / (arr_max - arr_min + 1e-18)

fig, ax = plt.subplots(1,2,figsize=(14,5))
ax[0].imshow(img)
i = ax[1].imshow(grad_eval,cmap="jet",alpha=0.8)
fig.colorbar(i)
# Out:
# (299, 299, 3)
